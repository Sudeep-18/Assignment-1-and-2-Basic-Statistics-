# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# Q7) Calculate Mean, Median, Mode, Variance, Standard Deviation, Range &     comment about the values / draw inferences, for the given dataset
# -	For Points,Score,Weigh>
# Find Mean, Median, Mode, Variance, Standard Deviation, and Range and also Comment about the values/ Draw some inferences.
# Use Q7.csv file

# %%
q7_df=pd.read_csv("q7.csv")

# %%
q7_df.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
Mean_points = q7_df.Points.mean()
Mean_score = q7_df.Score.mean()
Mean_weigh = q7_df.Weigh.mean()

# %%
print('Mean points = ',Mean_points)
print('Mean score = ',Mean_score)
print('Mean weigh = ',Mean_weigh)
# Out:
# Mean points =  3.5965625000000006
# Mean score =  3.2172499999999995
# Mean weigh =  17.848750000000003

# %%
Median_points = q7_df.Points.median()
Median_score = q7_df.Score.median()
Median_weigh = q7_df.Weigh.median()

# %%
print('Median points = ',Median_points)
print('Median score = ',Median_score)
print('Median weigh = ',Median_weigh)
# Out:
# Median points =  3.6950000000000003
# Median score =  3.325
# Median weigh =  17.71

# %%
Std_points = q7_df.Points.std()
Std_score = q7_df.Score.std()
Std_weigh = q7_df.Weigh.std()

# %%
print('Std points = ',Std_points)
print('Std score = ',Std_score)
print('Std weigh = ',Std_weigh)
# Out:
# Std points =  0.5346787360709716
# Std score =  0.9784574429896967
# Std weigh =  1.7869432360968431

# %%
Variance_points = q7_df.Points.var()
Variance_score = q7_df.Score.var()
Variance_weigh = q7_df.Weigh.var()

# %%
print('Variance points = ',Variance_points)
print('Variance score = ',Variance_score)
print('Variance weigh = ',Variance_weigh)
# Out:
# Variance points =  0.28588135080645166
# Variance score =  0.9573789677419356
# Variance weigh =  3.193166129032258

# %%
print(" The mode for points : ",stats.mode(q7_df['Points']))
print(" The mode for score : ",stats.mode(q7_df['Score'])) 
print(" The mode for weigh : ",stats.mode(q7_df['Weigh']))
# Out:
#  The mode for points :  ModeResult(mode=array([3.07]), count=array([3]))
#  The mode for score :  ModeResult(mode=array([3.44]), count=array([3]))
#  The mode for weigh :  ModeResult(mode=array([17.02]), count=array([2]))

# %%
Range_points=q7_df.Points.max()-q7_df.Points.min()
Range_score=q7_df.Score.max()-q7_df.Score.min()
Range_weigh=q7_df.Weigh.max()-q7_df.Weigh.min()

# %%
print('Range points = ',Range_points)
print('Range score = ',Range_score)
print('Range weigh = ',Range_weigh)
# Out:
# Range points =  2.17
# Range score =  3.9110000000000005
# Range weigh =  8.399999999999999

# %%
sns.distplot(q7_df['Points'])
# Out:
# <AxesSubplot:xlabel='Points', ylabel='Density'>

# %%
sns.distplot(q7_df['Score'])
# Out:
# <AxesSubplot:xlabel='Score', ylabel='Density'>

# %%
sns.distplot(q7_df['Weigh'])
# Out:
# <AxesSubplot:xlabel='Weigh', ylabel='Density'>

# %% [markdown]
# Q9) Calculate Skewness, Kurtosis & draw inferences on the following data
#       Cars speed and distance
# Use Q9_a.csv

# %%
df=pd.read_csv("q9_a.csv",index_col=0)

# %%
df.head(6 )
# Out:
#        speed  dist
# Index
# 1          4     2
# 2          4    10
# 3          7     4
# 4          7    22
# 5          8    16
# 6          9    10

# %%
df.skew()
# Out:
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
df.kurtosis()
# Out:
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
sns.distplot(df.iloc[:,0])
# Out:
# <AxesSubplot:xlabel='speed', ylabel='Density'>

# %%
sns.distplot(df.iloc[:,1])
# Out:
# <AxesSubplot:xlabel='dist', ylabel='Density'>

# %% [markdown]
# SP and Weight(WT)
# Use Q9_b.csv

# %%
q9_df= pd.read_csv("q9_b.csv",index_col=0)

# %%
q9_df
# Out:
#             SP         WT
# 1   104.185353  28.762059
# 2   105.461264  30.466833
# 3   105.461264  30.193597
# 4   113.461264  30.632114
# 5   104.461264  29.889149
# ..         ...        ...
# 77  169.598513  16.132947
# 78  150.576579  37.923113
# 79  151.598513  15.769625
# 80  167.944460  39.423099
# 81  139.840817  34.948615
#
# [81 rows x 2 columns]

# %%
q9_df.skew()
# Out:
# SP    1.611450
# WT   -0.614753
# dtype: float64

# %%
q9_df.kurtosis()
# Out:
# SP    2.977329
# WT    0.950291
# dtype: float64

# %%
sns.distplot(q9_df.iloc[:,0])
# Out:
# <AxesSubplot:xlabel='SP', ylabel='Density'>

# %%
sns.distplot(q9_df.iloc[:,1])
# Out:
# <AxesSubplot:xlabel='WT', ylabel='Density'>

# %% [markdown]
# Q11)  Suppose we want to estimate the average weight of an adult male in    Mexico. We draw a random sample of 2,000 men from a population of 3,000,000 men and weigh them. We find that the average person in our sample weighs 200 pounds, and the standard deviation of the sample is 30 pounds. Calculate 94%,98%,96% confidence interval?

# %%
stats.t.interval(0.94,loc=200,scale = 30/np.sqrt(2000),df=1999)
# Out:
# (198.7376089443071, 201.2623910556929)

# %%
stats.t.interval(0.98,loc=200,scale = 30/np.sqrt(2000),df=1999)
# Out:
# (198.4381860483216, 201.5618139516784)

# %%
stats.t.interval(0.96,loc=200,scale = 30/np.sqrt(2000),df=1999)
# Out:
# (198.6214037429732, 201.3785962570268)

# %% [markdown]
#  q12) Below are the scores obtained by a student in tests
# 34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56

# %%
df=[34,36,36,38,38,39,40,40,41,41,41,41,42,42,45,49,56]
df
# Out:
# [34, 36, 36, 38, 38, 39, 40, 40, 41, 41, 41, 41, 42, 42, 45, 49, 56]

# %%
sns.boxplot(df)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Q 20) Calculate probability from the given dataset for the below cases
#
# Data _set: Cars.csv
# Calculate the probability of MPG  of Cars for the below cases.

# %%
cars_df=pd.read_csv("cars.csv")

# %%
cars_df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %% [markdown]
# a.	P(MPG>38)

# %%
cars_df.MPG.mean()
# Out:
# 34.422075728024666

# %%
cars_df.MPG.std()
# Out:
# 9.131444731795982

# %%
1-stats.norm.cdf(38,loc=34.422075728024666,scale=9.131444731795982)
# Out:
# 0.3475939251582705

# %% [markdown]
# b.	P(MPG<40)

# %%
stats.norm.cdf(40,loc=34.422075728024666,scale=9.131444731795982)
# Out:
# 0.7293498762151616

# %% [markdown]
# c . P (20<MPG<50)

# %%
A=stats.norm.cdf(20,loc=34.422075728024666,scale=9.131444731795982)
B=stats.norm.cdf(50,loc=34.422075728024666,scale=9.131444731795982)
print(B-A)
# Out:
# 0.8988689169682046

# %% [markdown]
# Q 21) Check whether the data follows normal distribution
# a)	Check whether the MPG of Cars follows Normal Distribution
#         Dataset: Cars.csv

# %%
sns.distplot(cars_df.MPG)
# Out:
# <AxesSubplot:xlabel='MPG', ylabel='Density'>

# %% [markdown]
# b)	Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist)  from wc-at data set  follows Normal Distribution
#        Dataset: wc-at.csv

# %%
wcat_df=pd.read_csv('wc-at.csv')
wcat_df
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
sns.distplot(wcat_df.Waist)
# Out:
# <AxesSubplot:xlabel='Waist', ylabel='Density'>

# %%
sns.distplot(wcat_df.AT)
# Out:
# <AxesSubplot:xlabel='AT', ylabel='Density'>

# %% [markdown]
# Q 22) Calculate the Z scores of  90% confidence interval,94% confidence interval, 60% confidence interval

# %%
stats.norm.ppf(0.90)
# Out:
# 1.2815515655446004

# %%
stats.norm.ppf(0.94)
# Out:
# 1.5547735945968535

# %%
stats.norm.ppf(0.60)
# Out:
# 0.2533471031357997

# %% [markdown]
# 23) Calculate the t scores of 95% confidence interval, 96% confidence interval, 99% confidence interval for sample size of 25

# %%
stats.t.ppf(0.95,25)
# Out:
# 1.7081407612518986

# %%
stats.t.ppf(0.96,25)
# Out:
# 1.8248284689556018

# %%
stats.t.ppf(0.99,25)
# Out:
# 2.4851071754106413

# %% [markdown]
# 24) A Government  company claims that an average light bulb lasts 270 days. A researcher randomly selects 18 bulbs for testing. The sampled bulbs last an average of 260 days, with a standard deviation of 90 days. If the CEO's claim were true, what is the probability that 18 randomly selected bulbs would have an average life of no more than 260 days

# %%
t= (260-270)/(90/np.sqrt(18))

# %%
t
# Out:
# -0.4714045207910317

# %%
stats.t.cdf(t,17)
# Out:
# 0.32167253567098364
